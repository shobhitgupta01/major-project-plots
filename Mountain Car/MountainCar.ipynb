# %% [markdown]
# # Plots for Mountain Car Game
#
# ## Deep Q learning - Training data

# %%
% matplotlib inline 

import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('results_DQN_model_1.csv')


#Storing the different columns in variables
episodes = df['episode']
epsilon = df['epsilon']
score = df['score']
average_score=df['average_score']
total_reward=df['total_reward']
average_reward=df['average_reward']


plt.title("Scores for Deep Learning Model(Training)")
plt.xlabel("Episode")
plt.ylabel("Score")
plt.plot(episodes,score,'c-')

plt.savefig('outputs/dql_score1.png')
plt.show()

# %%
#Average Scores
plt.title("Average scores for Deep Learning Model(Training)")
plt.xlabel("Episode")
plt.ylabel("Average Score")
plt.plot(episodes,average_score,'b-')

plt.savefig('outputs/dql_avg_score.png')
plt.show()

# %%
plt.title("Decay of Exploration Factor")
plt.xlabel("Episode")
plt.ylabel("Exploration Factor")
plt.plot(episodes,epsilon,'r--')

plt.savefig('outputs/dql_decay.png')
plt.show()

# %%
plt.title("Total rewards for Deep Learning Model(Training)")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.plot(episodes,total_reward,'g-')

plt.savefig('outputs/dql_rewards1.png')
plt.show()

# %%
plt.title("Average rewards for Deep Learning Model(Training)")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.plot(episodes,average_reward,'b-')

plt.savefig('outputs/dql_avg_rewards1.png')
plt.show()

# %%
#Combining the graphs for Deep Learning Training Data

fig = plt.figure(figsize=(12,8))

ax1 = plt.subplot2grid((3,2),(0,0),rowspan=1,colspan=1)
ax2 = plt.subplot2grid((3,2),(0,1),rowspan=1,colspan=1)
ax3 = plt.subplot2grid((3,2),(1,0),rowspan=1,colspan=1)
ax4 = plt.subplot2grid((3,2),(1,1),rowspan=1,colspan=1)
ax5 = plt.subplot2grid((3,2),(2,0),rowspan=1,colspan=2)


#Total Scores
ax1.set_title("Scores for Deep Learning Model(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episodes,score,'c-')


#Average Scores
ax2.set_title("Average scores for Deep Learning Model(Training)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Average Score")
ax2.plot(episodes,average_score,'b-')


#Exploration Factor
ax3.set_title("Decay of Exploration Factor")
ax3.set_xlabel("Episode")
ax3.set_ylabel("Exploratino Factor")
ax3.plot(episodes,epsilon,'r--')


#Total Rewards
ax4.set_title("Total rewards for Deep Learning Model(Training)")
ax4.set_xlabel("Episode")
ax4.set_ylabel("Total Reward")
ax4.plot(episodes,total_reward,'g-')


#Average rewards

ax5.set_title("Average rewards for Deep Learning Model(Training)")
ax5.set_xlabel("Episode")
ax5.set_ylabel("Average Reward")
ax5.plot(episodes,average_reward,'y-')

plt.tight_layout()
plt.show()
plt.savefig('outputs/dql_1.png')

# %% [markdown]
# ## Deep Q learning - Testing Data

# %%
df2 = pd.read_csv('test_results_DQN_model1.csv')


#Storing the different columns in variables
episodes2 = df2['episode']
epsilon2 = df2['epsilon']
score2 = df2['score']
average_score2=df2['average_score']
total_reward2=df2['total_reward']
average_reward2=df2['average_reward']


plt.title("Scores for Deep Learning Model(Testing)")
plt.xlabel("Episode")
plt.ylabel("Score")
plt.plot(episodes2,score2,'c-')

plt.savefig('outputs/dql_score2.png')
plt.show()

# %%
#Average Scores
plt.title("Average scores for Deep Learning Model(Testing)")
plt.xlabel("Episode")
plt.ylabel("Average Score")
plt.plot(episodes2,average_score2,'b-')

plt.savefig('outputs/dql_avg_score2.png')
plt.show()

# %%
plt.title("Decay of Exploration Factor")
plt.xlabel("Episode")
plt.ylabel("Exploration Factor")
plt.plot(episodes2,epsilon2,'r--')

plt.savefig('outputs/dql_decay2.png')
plt.show()

# %%
plt.title("Total rewards for Deep Learning Model(Testing)")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.plot(episodes2,total_reward2,'g-')
plt.savefig('outputs/dql_total_rewards2.png')

plt.show()

# %%
plt.title("Average rewards for Deep Learning Model(Testing)")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.plot(episodes,average_reward,'b-')

plt.savefig('outputs/dql_avg_rewards.png')
plt.show()

# %%
#Combining the graphs for Deep Learning Testing Data

fig = plt.figure(figsize=(12,8))

ax1 = plt.subplot2grid((3,2),(0,0),rowspan=1,colspan=1)
ax2 = plt.subplot2grid((3,2),(0,1),rowspan=1,colspan=1)
ax3 = plt.subplot2grid((3,2),(1,0),rowspan=1,colspan=1)
ax4 = plt.subplot2grid((3,2),(1,1),rowspan=1,colspan=1)
ax5 = plt.subplot2grid((3,2),(2,0),rowspan=1,colspan=2)


#Total Scores
ax1.set_title("Scores for Deep Learning Model(Testing)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episodes2,score2,'c-')


#Average Scores
ax2.set_title("Average scores for Deep Learning Model(Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Average Score")
ax2.plot(episodes2,average_score2,'b-')


#Exploration Factor
ax3.set_title("Decay of Exploration Factor")
ax3.set_xlabel("Episode")
ax3.set_ylabel("Exploratino Factor")
ax3.plot(episodes2,epsilon2,'r--')


#Total Rewards
ax4.set_title("Total rewards for Deep Learning Model(Testing)")
ax4.set_xlabel("Episode")
ax4.set_ylabel("Total Reward")
ax4.plot(episodes2,total_reward2,'g-')


#Average rewards

ax5.set_title("Average rewards for Deep Learning Model(Testing)")
ax5.set_xlabel("Episode")
ax5.set_ylabel("Average Reward")
ax5.plot(episodes2,average_reward2,'y-')

plt.tight_layout()
plt.show()

plt.savefig('outputs/dql_2.png')

# %% [markdown]
# ## Comparison of Training and Testing Data for Deep Q Learning

# %%
#Total Scores
fig = plt.figure(figsize=(12,4))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)


#Training
ax1.set_title("Scores for Deep Learning Model(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episodes,score,'c-')

#Testing
ax2.set_title("Scores for Deep Learning Model(Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Score")
ax2.plot(episodes2,score2,'c-')

plt.tight_layout()
plt.savefig('outputs/cmp_dql_score.png')
plt.show()

# %%
#Average Scores
fig = plt.figure(figsize=(12,4))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)

#Training
ax1.set_title("Average scores for Deep Learning Model (Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Average Score")
ax1.plot(episodes,average_score,'b-')

#Testing
ax2.set_title("Average scores for Deep Learning Model (Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Average Score")
ax2.plot(episodes2,average_score2,'b-')

plt.tight_layout()
plt.savefig('outputs/cmp_dql_avg_score.png')
plt.show()

# %%
#Total Reward
fig = plt.figure(figsize=(12,4))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)

#Training
ax1.set_title("Total rewards for Deep Learning Model (Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Total Reward")
ax1.plot(episodes,total_reward,'g-')

#Testing
ax2.set_title("Total rewards for Deep Learning Model (Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Total Reward")
ax2.plot(episodes2,total_reward2,'g-')


plt.tight_layout()
plt.show()
plt.savefig('outputs/cmp_dql_total_reward.png')

# %%
#Average Rewards
fig = plt.figure(figsize=(12,4))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)

#Training
ax1.set_title("Average rewards for Deep Learning Model(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Average Reward")
ax1.plot(episodes,average_reward,'y-')

#Testing
ax2.set_title("Average rewards for Deep Learning Model(Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Average Reward")
ax2.plot(episodes2,average_reward2,'y-')

plt.tight_layout()
plt.show()
plt.savefig('outputs/cmp_dql_avg_reward.png')

# %% [markdown]
# ## Table based Q learning - Training Data

# %%
df3 = pd.read_csv('results_Q_learning_agent.csv')


#Storing the different columns in variables
episode3 = df3['episode']
epsilon3 = df3['epsilon']
score3 = df3['score']
average_score3=df3['average_score']
total_reward3=df3['total_reward']
average_reward3=df3['average_reward']


#total Score
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Score for Q-Learning(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode3,score3,'c-',linewidth="0.5")

plt.savefig('outputs/ql_score1.png')
plt.show()

# %%
#Average Scores
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Average Score for Q-Learning(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode3,average_score3,'b-',linewidth="0.7")


plt.show()

plt.savefig('outputs/ql_avg_score1.png')

plt.show()

# %%
#Total Rewards
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Total Reward for Q-Learning(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode3,total_reward3,'g-',linewidth="0.5")

plt.savefig('outputs/ql_total_reward1.png')
plt.show()

# %%
#Average Rewards
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Average Reward for Q-Learning(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode3,average_reward3,'r-',linewidth="0.5")

plt.savefig('outputs/ql_avg_rev1.png')
plt.show()

# %%
#Combined graph for Q learning(Testing)

fig = plt.figure(figsize=(12,8))

ax1 = plt.subplot2grid((2,2),(0,0))
ax2 = plt.subplot2grid((2,2),(0,1))
ax3 = plt.subplot2grid((2,2),(1,0))
ax4 = plt.subplot2grid((2,2),(1,1))

#Scores
ax1.set_title("Score for Q-Learning(Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode3,score3,'c-',linewidth="0.5")


#Average Scores
ax2.set_title("Average Score for Q-Learning(Training)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Score")
ax2.plot(episode3,average_score3,'b-',linewidth="0.7")

#Total Rewards
ax3.set_title("Total Reward for Q-Learning(Training)")
ax3.set_xlabel("Episode")
ax3.set_ylabel("Score")
ax3.plot(episode3,total_reward3,'g-',linewidth="0.5")

#Average Rewards
ax4.set_title("Average Reward for Q-Learning(Training)")
ax4.set_xlabel("Episode")
ax4.set_ylabel("Score")
ax4.plot(episode3,average_reward3,'r-',linewidth="0.5")


plt.tight_layout()
plt.show()
plt.savefig('outputs/ql_1.png')

# %% [markdown]
# ## Table based Q learning - Testing Data

# %%
df4 = pd.read_csv('test_results_Q_learning_agent.csv')


#Storing the different columns in variables
episode4 = df4['episode']
epsilon4 = df4['epsilon']
score4 = df4['score']
average_score4=df4['average_score']
total_reward4=df4['total_reward']
average_reward4=df4['average_reward']


#total Score
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Score for Q-Learning(Testing)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode4,score4,'c-')

plt.savefig('outputs/ql_score2.png')

plt.show()

# %%
#Average Scores
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Average Score for Q-Learning(Testing)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode4,average_score4,'b-')

plt.savefig('outputs/ql_avg_score2.png')

plt.show()

# %%
#Total Rewards
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Total Reward for Q-Learning(Testing)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode4,total_reward4,'g-')

plt.savefig('outputs/ql_total_reward2.png')

plt.show()

# %%
#Average Rewards
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Average Reward for Q-Learning(Testing)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode4,average_reward4,'r-')

plt.savefig('outputs/ql_avg_reward2.png')

plt.show()

# %% [markdown]
# ## Comparison of Training and Testing Data for Q Learning

# %%
#Total Scores
fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)


#Training
ax1.set_title("Scores for Q Learning (Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")
ax1.plot(episode3,score3,'c-',linewidth="0.7")

#Testing
ax2.set_title("Scores for Q Learning (Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Score")
ax2.plot(episode4,score4,'c-')

plt.tight_layout()

plt.savefig('outputs/cmp_ql_score.png')
plt.show()

# %%
#Average Scores
fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)

#Training
ax1.set_title("Average scores for Q Learning (Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Average Score")
ax1.plot(episode3,average_score3,'b-')

#Testing
ax2.set_title("Average scores for Q Learning Model (Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Average Score")
ax2.plot(episode4,average_score4,'b-')

plt.tight_layout()
plt.savefig('outputs/cmp_ql_avg_score.png')
plt.show()

# %%
#Total Reward
fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)

#Training
ax1.set_title("Total reward for Q Learning (Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Total Reward")
ax1.plot(episode3,total_reward3,'g-',linewidth='0.7')

#Testing
ax2.set_title("Total reward for Deep Learning Model (Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Total Reward")
ax2.plot(episode4,total_reward4,'g-')


plt.tight_layout()
plt.savefig('outputs/cmp_ql_total_reward.png')
plt.show()

# %%
#Average Rewards
fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,2),(0,0),colspan=1)
ax2 = plt.subplot2grid((1,2),(0,1),colspan=2)

#Training
ax1.set_title("Average rewards for Q Learning (Training)")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Average Reward")
ax1.plot(episode3,average_reward3,'y-')

#Testing
ax2.set_title("Average rewards for Q Learning (Testing)")
ax2.set_xlabel("Episode")
ax2.set_ylabel("Average Reward")
ax2.plot(episode4,average_reward4,'y-')

plt.tight_layout()
plt.savefig('outputs/cmp_ql_avg_reward.png')
plt.show()

# %% [markdown]
# ## Comparison of Deep Q learning, Q learning and Random action (testing)

# %%
#Importing the random action Data
df5 = pd.read_csv('test_results_random_guessing.csv')


#Storing the different columns in variables
episode5 = df5['episode']
epsilon5 = df5['epsilon']
score5 = df5['score']
average_score5=df5['average_score']
total_reward5=df5['total_reward']
average_reward5=df5['average_reward']

# %%
#Scores

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Scores")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Score")

ax1.plot(episodes2,score2,'c-',label="Deep Q-learning",linewidth=4)

ax1.plot(episode4,score4,'r-.',label="Q-learning",linewidth=4)

ax1.plot(episode5,score5,'b-',label="Random Guess",linewidth=4)

ax1.legend()

plt.tight_layout()
plt.savefig('outputs/cmp_score.png')
plt.show()

# %%
# Average Scores

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Average Scores")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Average Score")

ax1.plot(episodes2,average_score2,'c-',label="Deep Q-learning",linewidth=4)

ax1.plot(episode4,average_score4,'r-.',label="Q-learning",linewidth=4)

ax1.plot(episode5,average_score5,'b-',label="Random Guess",linewidth=4)

ax1.legend()

plt.tight_layout()
plt.savefig('outputs/cmp_avg_score.png')
plt.show()

# %%
# Total rewards

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Total Rewards")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Total Rewards")

ax1.plot(episodes2,total_reward2,'c-',label="Deep Q-learning",linewidth=4)

ax1.plot(episode4,total_reward4,'r-.',label="Q-learning",linewidth=4)

ax1.plot(episode5,total_reward5,'b-',label="Random Guess",linewidth=4)

ax1.legend()

plt.tight_layout()
plt.savefig('outputs/cmp_total_reward.png')
plt.show()

# %%
# Average rewards

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Average Rewards")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Average Rewards")

ax1.plot(episodes2,average_reward2,'c-',label="Deep Q-learning",linewidth=4)

ax1.plot(episode4,average_reward4,'r-.',label="Q-learning",linewidth=4)

ax1.plot(episode5,average_reward5,'b-',label="Random Guess",linewidth=4)

ax1.legend()

plt.tight_layout()
plt.savefig('outputs/cmp_avg_reward.png')
plt.show()
