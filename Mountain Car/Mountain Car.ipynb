# %% [markdown]
# # Plots for CartPole Game
#
# ## Deep Q learning - Training data

# %%
% matplotlib inline 

import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('results_DQN_model_1.csv')


#Storing the different columns in variables
episodes = df['episode']
epsilon = df['epsilon']
score = df['score']
average_score=df['average_score']
total_reward=df['total_reward']
average_reward=df['average_reward']


plt.title("Scores for Deep Learning Model",fontsize=15)
plt.xlabel("Episode",fontsize=13)
plt.ylabel("Score",fontsize=13)
plt.plot(episodes,score,'c-')

#PLotting min and max values
ymax=max(score)
ymin=min(score)

#xmin
xmin = df.loc[df['score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              

xmin = min(xmin['episode'])


#xmax
xmax = df.loc[df['score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(ymin)+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(ymax)+')',fontsize=11)

plt.savefig('outputs/dql_score.png')
plt.show()

# %%
#Average Scores
plt.title("Average scores for Deep Learning Model(Training)",fontsize=15)
plt.xlabel("Episode",fontsize=13)
plt.ylabel("Average Score",fontsize=13)
plt.plot(episodes,average_score,'b-')

#PLotting min and max values
ymax=max(average_score)
ymin=min(average_score)

#xmin
xmin = df.loc[df['average_score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              

xmin = min(xmin['episode'])


#xmax
xmax = df.loc[df['average_score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


plt.savefig('outputs/dql_avg_score.png')
plt.show()

# %%
plt.title("Decay of Exploration Factor")
plt.xlabel("Episode")
plt.ylabel("Exploration Factor")
plt.plot(episodes,epsilon,'r--')


#PLotting min and max values
ymax=max(epsilon)
ymin=min(epsilon)

#xmin
xmin = df.loc[df['epsilon']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df.loc[df['epsilon']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'b.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')')

#plotting max coordinates
plt.plot(xmax,ymax,'b.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')')


plt.savefig('outputs/dql_decay.png')
plt.show()

# %%
plt.title("Total rewards for Deep Learning Model(Training)",fontsize=15)
plt.xlabel("Episode",fontsize=13)
plt.ylabel("Total Reward",fontsize=13)
plt.plot(episodes,total_reward,'g-')

#PLotting min and max values
ymax=max(total_reward)
ymin=min(total_reward)

#xmin
xmin = df.loc[df['total_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df.loc[df['total_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



plt.savefig('outputs/dql_total_reward.png')
plt.show()

# %%
plt.title("Average rewards for Deep Learning Model(Training)",fontsize=15)
plt.xlabel("Episode",fontsize=13)
plt.ylabel("Average Reward",fontsize=13)
plt.plot(episodes,average_reward,'m-')

#PLotting min and max values
ymax=max(average_reward)
ymin=min(average_reward)

#xmin
xmin = df.loc[df['average_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df.loc[df['average_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



plt.savefig('outputs/dql_avg_rewards.png')
plt.show()

# %% [markdown]
# ## Deep Q learning - Testing Data

# %%
df2 = pd.read_csv('test_results_DQN_model1.csv')


#Storing the different columns in variables
episodes2 = df2['episode']
epsilon2 = df2['epsilon']
score2 = df2['score']
average_score2=df2['average_score']
total_reward2=df2['total_reward']
average_reward2=df2['average_reward']

# %% [markdown]
# ## Table based Q learning - Training Data

# %%
df3 = pd.read_csv('results_Q_learning_agent.csv')


#Storing the different columns in variables
episode3 = df3['episode']
epsilon3 = df3['epsilon']
score3 = df3['score']
average_score3=df3['average_score']
total_reward3=df3['total_reward']
average_reward3=df3['average_reward']
table_length = df3['Q_table_length']



#total Score
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Score for Q-Learning(Training)",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Score",fontsize=13)
ax1.plot(episode3,score3,'c-',linewidth="0.5")


#PLotting min and max values
ymax=max(score3)
ymin=min(score3)

#xmin
xmin = df3.loc[df3['score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df3.loc[df3['score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


plt.savefig('outputs/QL_score.png')
plt.show()

# %%
#Average Scores
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Average Score for Q-Learning(Training)",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Average Score",fontsize=13)
ax1.plot(episode3,average_score3,'b-',linewidth="0.7")


#PLotting min and max values
ymax=max(average_score3)
ymin=min(average_score3)

#xmin
xmin = df3.loc[df3['average_score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df3.loc[df3['average_score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



plt.savefig('outputs/QL_avg_score.png')

plt.show()

# %%
#Total Rewards
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Total Reward for Q-Learning(Training)",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Total Reward",fontsize=13)
ax1.plot(episode3,total_reward3,'g-',linewidth="0.5")

#PLotting min and max values
ymax=max(total_reward3)
ymin=min(total_reward3)

#xmin
xmin = df3.loc[df3['total_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df3.loc[df3['total_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



plt.savefig('outputs/QL_total_reward.png')
plt.show()

# %%
#Average Rewards
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Average Reward for Q-Learning(Training)",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Average Reward",fontsize=13)
ax1.plot(episode3,average_reward3,'m-',linewidth="0.5")

#PLotting min and max values
ymax=max(average_reward3)
ymin=min(average_reward3)

#xmin
xmin = df3.loc[df3['average_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df3.loc[df3['average_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



plt.savefig('outputs/QL_avg_rev.png')
plt.show()

# %%
#Q table length
fig = plt.figure(figsize=(15,9))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Score for Q-Learning(Training)",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Score",fontsize=13)
ax1.plot(episode3,table_length,'r-.')


#PLotting min and max values
ymax=max(table_length)
ymin=min(table_length)

#xmin
xmin = df3.loc[df3['Q_table_length']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df3.loc[df3['Q_table_length']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
plt.plot(xmin,ymin,'r.')
plt.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
plt.plot(xmax,ymax,'r.')
plt.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


plt.savefig('outputs/QL Q Table length.png')
plt.show()

# %% [markdown]
# # Q Learning Agent vs DQN Agent

# %%
#Score vs Episodes
fig = plt.figure(figsize=(12,5))

ax1 = plt.subplot2grid((1,2),(0,0))
ax1.set_title('Q Learning Score',fontsize=15)
ax1.set_xlabel('Episode',fontsize=13)
ax1.set_ylabel('Score',fontsize=13)
ax1.plot(episode4,score4,'c-')
#PLotting min and max values
ymax=max(score4)
ymin=min(score4)

#xmin
xmin = df4.loc[df4['score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.')
ax1.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.')
ax1.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax2 = plt.subplot2grid((1,2),(0,1))
ax2.set_title('DQL Score',fontsize=15)
ax2.set_xlabel('Episode',fontsize=13)
ax2.set_ylabel('Score',fontsize=13)
ax2.plot(episodes2,score2,'c-')
#PLotting min and max values
ymax=max(score2)
ymin=min(score2)

#xmin
xmin = df2.loc[df2['score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax2.plot(xmin,ymin,'r.')
ax2.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax2.plot(xmax,ymax,'r.')
ax2.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



plt.tight_layout()

plt.show()

plt.savefig('outputs/comparison of QL and DQL scores.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f60db089bbf6> in <module>()
#       6 ax1.set_xlabel('Episode',fontsize=13)
#       7 ax1.set_ylabel('Score',fontsize=13)
# ----> 8 ax1.plot(episode4,score4,'c-')
#       9 #PLotting min and max values
#      10 ymax=max(score4)
#
# NameError: name 'episode4' is not defined

# %%
#Average Score vs Episodes
fig = plt.figure(figsize=(12,5))

ax1 = plt.subplot2grid((1,2),(0,0))
ax1.set_title('Q Learning Average Score',fontsize=15)
ax1.set_xlabel('Episode',fontsize=13)
ax1.set_ylabel('Score',fontsize=13)
ax1.plot(episode4,average_score4,'g-')

#PLotting min and max values
ymax=max(average_score4)
ymin=min(average_score4)

#xmin
xmin = df4.loc[df4['average_score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['average_score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.')
ax1.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.')
ax1.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax2 = plt.subplot2grid((1,2),(0,1))
ax2.set_title('DQL Average Score',fontsize=15)
ax2.set_xlabel('Episode',fontsize=13)
ax2.set_ylabel('Average Score',fontsize=13)
ax2.plot(episodes2,average_score2,'g-')

#PLotting min and max values
ymax=max(average_score2)
ymin=min(average_score2)

#xmin
xmin = df2.loc[df2['average_score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['average_score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax2.plot(xmin,ymin,'r.')
ax2.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax2.plot(xmax,ymax,'r.')
ax2.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


plt.tight_layout()

plt.show()

plt.savefig('outputs/comparison of QL and DQL average scores.png')

# %%
#Reward vs Episodes
fig = plt.figure(figsize=(12,5))

ax1 = plt.subplot2grid((1,2),(0,0))
ax1.set_title('Q Learning Total Reward',fontsize=15)
ax1.set_xlabel('Episode',fontsize=13)
ax1.set_ylabel('Reward',fontsize=13)
ax1.plot(episode4,total_reward4,'b-')

#PLotting min and max values
ymax=max(total_reward4)
ymin=min(total_reward4)

#xmin
xmin = df4.loc[df4['total_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['total_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.')
ax1.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.')
ax1.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


ax2 = plt.subplot2grid((1,2),(0,1))
ax2.set_title('DQL Total Reward',fontsize=15)
ax2.set_xlabel('Episode',fontsize=13)
ax2.set_ylabel('Reward',fontsize=13)
ax2.plot(episodes2,total_reward2,'b-')

#PLotting min and max values
ymax=max(total_reward2)
ymin=min(total_reward2)

#xmin
xmin = df2.loc[df2['total_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['total_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax2.plot(xmin,ymin,'r.')
ax2.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax2.plot(xmax,ymax,'r.')
ax2.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


plt.tight_layout()

plt.show()

plt.savefig('outputs/comparison of QL and DQL total rewards.png')

# %%
#Average Reward vs Episodes
fig = plt.figure(figsize=(12,5))

ax1 = plt.subplot2grid((1,2),(0,0))
ax1.set_title('Q Learning Average Reward',fontsize=15)
ax1.set_xlabel('Episode',fontsize=13)
ax1.set_ylabel('Average Reward',fontsize=13)
ax1.plot(episode4,average_reward4,'m-')
#PLotting min and max values
ymax=max(average_reward4)
ymin=min(average_reward4)

#xmin
xmin = df4.loc[df4['average_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['average_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.')
ax1.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.')
ax1.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)




ax2 = plt.subplot2grid((1,2),(0,1))
ax2.set_title('DQL Average Reward')
ax2.set_xlabel('Episode',fontsize=13)
ax2.set_ylabel('Average Reward',fontsize=13)
ax2.plot(episodes2,average_reward2,'m-')

#PLotting min and max values
ymax=max(average_reward2)
ymin=min(average_reward2)

#xmin
xmin = df2.loc[df2['average_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['average_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax2.plot(xmin,ymin,'r.')
ax2.text(xmin + 2,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax2.plot(xmax,ymax,'r.')
ax2.text(xmax + 2,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



plt.tight_layout()

plt.show()

plt.savefig('outputs/comparison of QL and DQL Average Reward.png')

# %% [markdown]
# ## Comparison of Deep Q learning, Q learning and Random action (testing)

# %%
#Importing the random action Data
df5 = pd.read_csv('test_results_random_guessing.csv')


#Storing the different columns in variables
episode5 = df5['episode']
epsilon5 = df5['epsilon']
score5 = df5['score']
average_score5=df5['average_score']
total_reward5=df5['total_reward']
average_reward5=df5['average_reward']

# %%
#Scores

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Scores",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Score",fontsize=13)

ax1.plot(episodes2,score2,'c--',label="Deep Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(score2)
ymin=min(score2)

#xmin
xmin = df2.loc[df2['score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax1.plot(episode4,score4,'r-.',label="Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(score4)
ymin=min(score4)

#xmin
xmin = df4.loc[df4['score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'k.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


ax1.plot(episode5,score5,'b-',label="Random Guess",linewidth=4)
#PLotting min and max values
ymax=max(score5)
ymin=min(score5)

#xmin
xmin = df5.loc[df5['score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df5.loc[df5['score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'k.',linewidth=8)
ax1.text(xmin+0.5 ,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+.05,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)

ax1.legend(prop={'size':16})

plt.tight_layout()
plt.savefig('outputs/comparison of scores.png')
plt.show()

# %%
# Average Scores

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Average Scores",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Average Score",fontsize=13)

ax1.plot(episodes2,average_score2,'c--',label="Deep Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(average_score2)
ymin=min(average_score2)

#xmin
xmin = df2.loc[df2['average_score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['average_score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax1.plot(episode4,average_score4,'r-.',label="Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(average_score4)
ymin=min(average_score4)

#xmin
xmin = df4.loc[df4['average_score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['average_score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax1.plot(episode5,average_score5,'b-',label="Random Guess",linewidth=4)
#PLotting min and max values
ymax=max(average_score5)
ymin=min(average_score5)

#xmin
xmin = df5.loc[df5['average_score']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df5.loc[df5['average_score']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'k.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax1.legend(prop={'size':16})

plt.tight_layout()
plt.savefig('outputs/comparison of average scores.png')
plt.show()

# %%
# Total rewards

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Total Rewards",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Total Rewards",fontsize=13)

ax1.plot(episodes2,total_reward2,'c--',label="Deep Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(total_reward2)
ymin=min(total_reward2)

#xmin
xmin = df2.loc[df2['total_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['total_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)




ax1.plot(episode4,total_reward4,'r-.',label="Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(total_reward4)
ymin=min(total_reward4)

#xmin
xmin = df4.loc[df4['total_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['total_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'k.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


ax1.plot(episode5,total_reward5,'b-',label="Random Guess",linewidth=4)
#PLotting min and max values
ymax=max(total_reward5)
ymin=min(total_reward5)

#xmin
xmin = df5.loc[df5['total_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df5.loc[df5['total_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'k.',linewidth=8)
ax1.text(xmin+0.5,ymin,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+0.5,ymax,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


ax1.legend(prop={'size':16})

plt.tight_layout()
plt.savefig('outputs/comparison of total rewards.png')
plt.show()

# %%
# Average rewards

fig = plt.figure(figsize=(15,6))

ax1 = plt.subplot2grid((1,1),(0,0))

ax1.set_title("Comparison of Average Rewards",fontsize=15)
ax1.set_xlabel("Episode",fontsize=13)
ax1.set_ylabel("Average Rewards",fontsize=13)

ax1.plot(episodes2,average_reward2,'c--',label="Deep Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(average_reward2)
ymin=min(average_reward2)

#xmin
xmin = df2.loc[df2['average_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df2.loc[df2['average_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'r.',linewidth=8)
ax1.text(xmin+0.5,ymin+5,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'r.',linewidth=8)
ax1.text(xmax+0.5,ymax+5,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)


ax1.plot(episode4,average_reward4,'r-.',label="Q-learning",linewidth=4)
#PLotting min and max values
ymax=max(average_reward4)
ymin=min(average_reward4)

#xmin
xmin = df4.loc[df4['average_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df4.loc[df4['average_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'k.',linewidth=8)
ax1.text(xmin+0.5,ymin+5,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+0.5,ymax+5,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax1.plot(episode5,average_reward5,'b-',label="Random Guess",linewidth=4)
#PLotting min and max values
ymax=max(average_reward5)
ymin=min(average_reward5)

#xmin
xmin = df5.loc[df5['average_reward']==ymin]

if xmin.shape[0]>1:
    xmin=(xmin.iloc[[0]]) 
              
xmin = min(xmin['episode'])


#xmax
xmax = df5.loc[df5['average_reward']==ymax]

if xmax.shape[0]>1:
    xmax=(xmax.iloc[[0]]) 
              
xmax=max(xmax['episode'])

#plotting min coordinates
ax1.plot(xmin,ymin,'k.',linewidth=8)
ax1.text(xmin+0.5,ymin+5,'min('+str(xmin)+','+str(round(ymin,2))+')',fontsize=11)

#plotting max coordinates
ax1.plot(xmax,ymax,'k.',linewidth=8)
ax1.text(xmax+0.5,ymax+5,'max('+str(xmax)+','+str(round(ymax,2))+')',fontsize=11)



ax1.legend(prop={'size':16})

plt.tight_layout()
plt.savefig('outputs/comparison of average rewards.png')
plt.show()
